# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline

# %%
df = pd.read_csv('./train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.loc[df["Survived"] == 1, 'Survived'] = True
df.loc[df["Survived"] == 0, 'Survived'] = False
df["Survived"] = pd.Categorical(df["Survived"])

# %%
df["Survived"]
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: category
# Categories (2, object): [False, True]

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# How many people has survived?

# %%
sns.histplot(data=df, x="Survived")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Count'>

# %% [markdown]
# Let's see how passengers was distributed over each attribute

# %%
sns.histplot(data=df, x="Pclass")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Count'>

# %%
sns.histplot(data=df, x="Age")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=df, x="Age", bins=range(0, 100, 10))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.catplot(data=df, x='Pclass', y='Age')

# %%
sns.catplot(data=df, x='Pclass', y='Fare')

# %% [markdown]
# Let's compare with our Y values

# %%
sns.barplot(data=df, x="Survived", y="Age")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.catplot(data=df, x="Age", col="Survived", kind='count')

# %% [markdown]
# garbage

# %%
sns.catplot(data=df, x="Sex", col="Survived", kind='count')

# %%
sns.catplot(data=df, x="Pclass", col="Survived", kind='count')

# %%
sns.catplot(x="Pclass", hue="Sex", col="Survived",
                data=df, kind="count",
                height=4, aspect=.7);

# %%
sns.barplot(data=df, x="Survived", y="Pclass")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Pclass'>

# %%
sns.catplot(data=df, x="Survived", y="Fare", kind="swarm")
# Out:
# /Users/vachara/.conda/envs/mlsession/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 68.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/vachara/.conda/envs/mlsession/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 41.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=df, x="Survived", y="Age", kind="swarm")
# Out:
# /Users/vachara/.conda/envs/mlsession/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
